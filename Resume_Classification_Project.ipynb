# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
os.listdir(r"C:\Users\hp\OneDrive\Desktop\Resumes")
# Out:
# ['Peoplesoft resumes',
#  'React Developer',
#  'SQL Developer Lightning insight',
#  'workday resumes']

# %%
pip install python-docx
# Out:
# Requirement already satisfied: python-docx in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from python-docx) (5.3.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from python-docx) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document
import os

file_path1 = []
category1 = []
directory1 = r"C:\Users\hp\OneDrive\Desktop\Resumes\Peoplesoft resumes"

for i in os.listdir(directory1):
    if i.endswith('.docx'):
        # Construct the full file path
        file_path = os.path.join(directory1, i)

        # Load the Word document
        doc = Document(file_path)

        # Extract text from the document
        full_text = []
        for paragraph in doc.paragraphs:
            full_text.append(paragraph.text)
        
        # Join all paragraphs into a single string
        document_text = '\n'.join(full_text)

        # Append the extracted text to file_path1
        file_path1.append(document_text)
        category1.append('PeopleSoft')  # Add category as before

# %%
data1 = pd.DataFrame(data = file_path1 , columns = ['Raw_Details'])
data1['Category1'] = category1
data1
# Out:
#                                          Raw_Details   Category1
# 0    Anubhav Kumar Singh\t\t\n\n  To work in a gl...  PeopleSoft
# 1  Murali\n\nExperience Summary \n\nI have 6 year...  PeopleSoft
# 2  \n\n\n\n\n\n\n\n\n\n\n\n\n\nPROFILE SUMMARY\n\...  PeopleSoft
# 3   PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...  PeopleSoft
# 4  PeopleSoft Administration\n \nVivekanand Sayan...  PeopleSoft
# 5  \nHaving 4.6 years of experience in PeopleSoft...  PeopleSoft
# 6  \nHaving 4.6 years of experience in PeopleSoft...  PeopleSoft
# 7   \n\nCAREER OBJECTIVE\t\t\n\nPursuing Peopleso...  PeopleSoft
# 8  Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...  PeopleSoft
# 9  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nC O N ...  PeopleSoft

# %%
file_path2 = []
category2 = []
directory2 = r"C:\Users\hp\OneDrive\Desktop\Resumes\React Developer"

for i in os.listdir(directory2):
    if i.endswith('.docx'):
        # Construct the full file path
        file_path = os.path.join(directory2, i)

        # Load the Word document
        doc = Document(file_path)

        # Extract text from the document
        full_text = []
        for paragraph in doc.paragraphs:
            full_text.append(paragraph.text)
        
        # Join all paragraphs into a single string
        document_text = '\n'.join(full_text)

        # Append the extracted text to file_path1
        file_path2.append(document_text)
        category2.append('React JS Developer')  # Add category as before

# %%
data2 = pd.DataFrame(data = file_path2 , columns = ['Raw_Details'])
data2['Category2'] = category2
data2
# Out:
#                                           Raw_Details           Category2
# 0   Name: Ravali P \n\n                           ...  React JS Developer
# 1     \nSUSOVAN  BAG   \nSeeking  a  challenging  ...  React JS Developer
# 2   Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...  React JS Developer
# 3   HARIPRIYA BATTINA \nExperience as UI Developer...  React JS Developer
# 4   KAMALAKAR REDDY. A \nLinked In: https://www.li...  React JS Developer
# 5   \nNaveen Sadhu\n\n\nTitle: software developer\...  React JS Developer
# 6    \nPRAGNYA PATTNAIK\n \n \n \n Expertise: \n \...  React JS Developer
# 7   \n\n 204,Sri geethika prestige,road number 10...  React JS Developer
# 8   \n\nThirupathamma Balla\n\nSUMMARY:\n\n2.8 yea...  React JS Developer
# 9   \nUi-Developer/ React JS Developer \nNAME: KRI...  React JS Developer
# 10  \nUi-Developer/ React JS Developer \nNAME: KRI...  React JS Developer
# 11  Kotani Durga Prasad\n\n\nObjective:\n\nAspiran...  React JS Developer
# 12  Venkatalakshmi Pedireddy\nSoftware Developer\n...  React JS Developer
# 13  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...  React JS Developer
# 14  MAREEDU LOKESH BABU\nPROFESSIONAL OVERVIEW\n  ...  React JS Developer
# 15  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...  React JS Developer
# 16  MD KHIZARUDDIN RAUF \n \t EXPERIENCE \n     \n...  React JS Developer
# 17  \nPranish Sonone\n\t\n\n\n\n\nCareer summary:\...  React JS Developer
# 18  Ranga Gaganam  \n \n \nHaving 1+ years of succ...  React JS Developer
# 19  SHAIK ABDUL SHARUK   \n2 years’ Experience in ...  React JS Developer

# %%
file_path3 = []
category3 = []
directory3 = r"C:\Users\hp\OneDrive\Desktop\Resumes\SQL Developer Lightning insight"

for i in os.listdir(directory3):
    if i.endswith('.docx'):
        # Construct the full file path
        file_path = os.path.join(directory3, i)

        # Load the Word document
        doc = Document(file_path)

        # Extract text from the document
        full_text = []
        for paragraph in doc.paragraphs:
            full_text.append(paragraph.text)
        
        # Join all paragraphs into a single string
        document_text = '\n'.join(full_text)

        # Append the extracted text to file_path1
        file_path3.append(document_text)
        category3.append('SQL Developer')

# %%
data3 = pd.DataFrame(data = file_path3 , columns = ['Raw_Details'])
data3['Category3'] = category3
data3
# Out:
#                                           Raw_Details      Category3
# 0   ANIL KUMAR MADDUKURI  \t\t\nSQL & MSBI Develop...  SQL Developer
# 1   \nAradhana Tripathi\n\nCurrent Location: Gachi...  SQL Developer
# 2   BUDDHA VAMSI                                  ...  SQL Developer
# 3   KAMBALLA PRADEEP                              ...  SQL Developer
# 4    \n                                        Res...  SQL Developer
# 5   SQL DEVELOPER\nName: -   Bandi prem sai\n\n\nW...  SQL Developer
# 6                                          SQL SER...  SQL Developer
# 7    RAJU PAVANA KUMARI\n\n\nProfessional Summary:...  SQL Developer
# 8                                       resume\n\n...  SQL Developer
# 9   Name: Ramesh\n\nCareer Objective: \n          ...  SQL Developer
# 10  B. vinod kumar\n\nOBJECTIVE:\nWilling to work ...  SQL Developer

# %%
file_path4 = []
category4 = []
directory4 = r"C:\Users\hp\OneDrive\Desktop\Resumes\workday resumes"

for i in os.listdir(directory4):
    if i.endswith('.docx'):
        # Construct the full file path
        file_path = os.path.join(directory4, i)

        # Load the Word document
        doc = Document(file_path)

        # Extract text from the document
        full_text = []
        for paragraph in doc.paragraphs:
            full_text.append(paragraph.text)
        
        # Join all paragraphs into a single string
        document_text = '\n'.join(full_text)

        # Append the extracted text to file_path1
        file_path4.append(document_text)
        category4.append('Workday')

# %%
data4 = pd.DataFrame(data = file_path4 , columns = ['Raw_Details'])
data4['Category4'] = category4
data4
# Out:
#                                           Raw_Details Category4
# 0   Chinna Subbarayudu M\nDOB: 06th March 1994\nNa...   Workday
# 1   \t\n\n\nName         : Gopi Krishna Reddy\n\t\...   Workday
# 2                                         \n      ...   Workday
# 3   \n\nJYOTI VERMA\t\t\t\t\t\n\n\n\n3 years of Ex...   Workday
# 4   \n\nMooraboyina Guravaiah\nWorkday Integration...   Workday
# 5   VENKATA SAIKRISHNA\n Workday Consultant\n\n\nP...   Workday
# 6   Rahul  (Techno Functional Consultant)  \nProfe...   Workday
# 7   Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...   Workday
# 8   Seeking suitable positions in Workday HCM  as ...   Workday
# 9   \nWORKDAY | HCM | FCM\nName \t\t: Kumar S.S\nR...   Workday
# 10                                                ...   Workday

# %%
resume_data = pd.concat([data1, data2, data3, data4], ignore_index=True)

# Display the combined DataFrame
resume_data
# Out:
#                                           Raw_Details   Category1  \
# 0     Anubhav Kumar Singh\t\t\n\n  To work in a gl...  PeopleSoft
# 1   Murali\n\nExperience Summary \n\nI have 6 year...  PeopleSoft
# 2   \n\n\n\n\n\n\n\n\n\n\n\n\n\nPROFILE SUMMARY\n\...  PeopleSoft
# 3    PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...  PeopleSoft
# 4   PeopleSoft Administration\n \nVivekanand Sayan...  PeopleSoft
# 5   \nHaving 4.6 years of experience in PeopleSoft...  PeopleSoft
# 6   \nHaving 4.6 years of experience in PeopleSoft...  PeopleSoft
# 7    \n\nCAREER OBJECTIVE\t\t\n\nPursuing Peopleso...  PeopleSoft
# 8   Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...  PeopleSoft
# 9   \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nC O N ...  PeopleSoft
# 10  Name: Ravali P \n\n                           ...         NaN
# 11    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...         NaN
# 12  Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...         NaN
# 13  HARIPRIYA BATTINA \nExperience as UI Developer...         NaN
# 14  KAMALAKAR REDDY. A \nLinked In: https://www.li...         NaN
# 15  \nNaveen Sadhu\n\n\nTitle: software developer\...         NaN
# 16   \nPRAGNYA PATTNAIK\n \n \n \n Expertise: \n \...         NaN
# 17  \n\n 204,Sri geethika prestige,road number 10...         NaN
# 18  \n\nThirupathamma Balla\n\nSUMMARY:\n\n2.8 yea...         NaN
# 19  \nUi-Developer/ React JS Developer \nNAME: KRI...         NaN
# 20  \nUi-Developer/ React JS Developer \nNAME: KRI...         NaN
# 21  Kotani Durga Prasad\n\n\nObjective:\n\nAspiran...         NaN
# 22  Venkatalakshmi Pedireddy\nSoftware Developer\n...         NaN
# 23  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...         NaN
# 24  MAREEDU LOKESH BABU\nPROFESSIONAL OVERVIEW\n  ...         NaN
# 25  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...         NaN
# 26  MD KHIZARUDDIN RAUF \n \t EXPERIENCE \n     \n...         NaN
# 27  \nPranish Sonone\n\t\n\n\n\n\nCareer summary:\...         NaN
# 28  Ranga Gaganam  \n \n \nHaving 1+ years of succ...         NaN
# 29  SHAIK ABDUL SHARUK   \n2 years’ Experience in ...         NaN
# 30  ANIL KUMAR MADDUKURI  \t\t\nSQL & MSBI Develop...         NaN
# 31  \nAradhana Tripathi\n\nCurrent Location: Gachi...         NaN
# 32  BUDDHA VAMSI                                  ...         NaN
# 33  KAMBALLA PRADEEP                              ...         NaN
# 34   \n                                        Res...         NaN
# 35  SQL DEVELOPER\nName: -   Bandi prem sai\n\n\nW...         NaN
# 36                                         SQL SER...         NaN
# 37   RAJU PAVANA KUMARI\n\n\nProfessional Summary:...         NaN
# 38                                      resume\n\n...         NaN
# 39  Name: Ramesh\n\nCareer Objective: \n          ...         NaN
# 40  B. vinod kumar\n\nOBJECTIVE:\nWilling to work ...         NaN
# 41  Chinna Subbarayudu M\nDOB: 06th March 1994\nNa...         NaN
# 42  \t\n\n\nName         : Gopi Krishna Reddy\n\t\...         NaN
# 43                                        \n      ...         NaN
# 44  \n\nJYOTI VERMA\t\t\t\t\t\n\n\n\n3 years of Ex...         NaN
# 45  \n\nMooraboyina Guravaiah\nWorkday Integration...         NaN
# 46  VENKATA SAIKRISHNA\n Workday Consultant\n\n\nP...         NaN
# 47  Rahul  (Techno Functional Consultant)  \nProfe...         NaN
# 48  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...         NaN
# 49  Seeking suitable positions in Workday HCM  as ...         NaN
# 50  \nWORKDAY | HCM | FCM\nName \t\t: Kumar S.S\nR...         NaN
# 51                                                ...         NaN
#
#              Category2      Category3 Category4
# 0                  NaN            NaN       NaN
# 1                  NaN            NaN       NaN
# 2                  NaN            NaN       NaN
# 3                  NaN            NaN       NaN
# 4                  NaN            NaN       NaN
# 5                  NaN            NaN       NaN
# 6                  NaN            NaN       NaN
# 7                  NaN            NaN       NaN
# 8                  NaN            NaN       NaN
# 9                  NaN            NaN       NaN
# 10  React JS Developer            NaN       NaN
# 11  React JS Developer            NaN       NaN
# 12  React JS Developer            NaN       NaN
# 13  React JS Developer            NaN       NaN
# 14  React JS Developer            NaN       NaN
# 15  React JS Developer            NaN       NaN
# 16  React JS Developer            NaN       NaN
# 17  React JS Developer            NaN       NaN
# 18  React JS Developer            NaN       NaN
# 19  React JS Developer            NaN       NaN
# 20  React JS Developer            NaN       NaN
# 21  React JS Developer            NaN       NaN
# 22  React JS Developer            NaN       NaN
# 23  React JS Developer            NaN       NaN
# 24  React JS Developer            NaN       NaN
# 25  React JS Developer            NaN       NaN
# 26  React JS Developer            NaN       NaN
# 27  React JS Developer            NaN       NaN
# 28  React JS Developer            NaN       NaN
# 29  React JS Developer            NaN       NaN
# 30                 NaN  SQL Developer       NaN
# 31                 NaN  SQL Developer       NaN
# 32                 NaN  SQL Developer       NaN
# 33                 NaN  SQL Developer       NaN
# 34                 NaN  SQL Developer       NaN
# 35                 NaN  SQL Developer       NaN
# 36                 NaN  SQL Developer       NaN
# 37                 NaN  SQL Developer       NaN
# 38                 NaN  SQL Developer       NaN
# 39                 NaN  SQL Developer       NaN
# 40                 NaN  SQL Developer       NaN
# 41                 NaN            NaN   Workday
# 42                 NaN            NaN   Workday
# 43                 NaN            NaN   Workday
# 44                 NaN            NaN   Workday
# 45                 NaN            NaN   Workday
# 46                 NaN            NaN   Workday
# 47                 NaN            NaN   Workday
# 48                 NaN            NaN   Workday
# 49                 NaN            NaN   Workday
# 50                 NaN            NaN   Workday
# 51                 NaN            NaN   Workday

# %%
resume_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Raw_Details  52 non-null     object
#  1   Category1    10 non-null     object
#  2   Category2    20 non-null     object
#  3   Category3    11 non-null     object
#  4   Category4    11 non-null     object
# dtypes: object(5)
# memory usage: 2.2+ KB

# %%
resume_data['Category'] = category1 + category2 + category3 + category4
resume_data
# Out:
#                                           Raw_Details   Category1  \
# 0     Anubhav Kumar Singh\t\t\n\n  To work in a gl...  PeopleSoft
# 1   Murali\n\nExperience Summary \n\nI have 6 year...  PeopleSoft
# 2   \n\n\n\n\n\n\n\n\n\n\n\n\n\nPROFILE SUMMARY\n\...  PeopleSoft
# 3    PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...  PeopleSoft
# 4   PeopleSoft Administration\n \nVivekanand Sayan...  PeopleSoft
# 5   \nHaving 4.6 years of experience in PeopleSoft...  PeopleSoft
# 6   \nHaving 4.6 years of experience in PeopleSoft...  PeopleSoft
# 7    \n\nCAREER OBJECTIVE\t\t\n\nPursuing Peopleso...  PeopleSoft
# 8   Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...  PeopleSoft
# 9   \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nC O N ...  PeopleSoft
# 10  Name: Ravali P \n\n                           ...         NaN
# 11    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...         NaN
# 12  Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...         NaN
# 13  HARIPRIYA BATTINA \nExperience as UI Developer...         NaN
# 14  KAMALAKAR REDDY. A \nLinked In: https://www.li...         NaN
# 15  \nNaveen Sadhu\n\n\nTitle: software developer\...         NaN
# 16   \nPRAGNYA PATTNAIK\n \n \n \n Expertise: \n \...         NaN
# 17  \n\n 204,Sri geethika prestige,road number 10...         NaN
# 18  \n\nThirupathamma Balla\n\nSUMMARY:\n\n2.8 yea...         NaN
# 19  \nUi-Developer/ React JS Developer \nNAME: KRI...         NaN
# 20  \nUi-Developer/ React JS Developer \nNAME: KRI...         NaN
# 21  Kotani Durga Prasad\n\n\nObjective:\n\nAspiran...         NaN
# 22  Venkatalakshmi Pedireddy\nSoftware Developer\n...         NaN
# 23  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...         NaN
# 24  MAREEDU LOKESH BABU\nPROFESSIONAL OVERVIEW\n  ...         NaN
# 25  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...         NaN
# 26  MD KHIZARUDDIN RAUF \n \t EXPERIENCE \n     \n...         NaN
# 27  \nPranish Sonone\n\t\n\n\n\n\nCareer summary:\...         NaN
# 28  Ranga Gaganam  \n \n \nHaving 1+ years of succ...         NaN
# 29  SHAIK ABDUL SHARUK   \n2 years’ Experience in ...         NaN
# 30  ANIL KUMAR MADDUKURI  \t\t\nSQL & MSBI Develop...         NaN
# 31  \nAradhana Tripathi\n\nCurrent Location: Gachi...         NaN
# 32  BUDDHA VAMSI                                  ...         NaN
# 33  KAMBALLA PRADEEP                              ...         NaN
# 34   \n                                        Res...         NaN
# 35  SQL DEVELOPER\nName: -   Bandi prem sai\n\n\nW...         NaN
# 36                                         SQL SER...         NaN
# 37   RAJU PAVANA KUMARI\n\n\nProfessional Summary:...         NaN
# 38                                      resume\n\n...         NaN
# 39  Name: Ramesh\n\nCareer Objective: \n          ...         NaN
# 40  B. vinod kumar\n\nOBJECTIVE:\nWilling to work ...         NaN
# 41  Chinna Subbarayudu M\nDOB: 06th March 1994\nNa...         NaN
# 42  \t\n\n\nName         : Gopi Krishna Reddy\n\t\...         NaN
# 43                                        \n      ...         NaN
# 44  \n\nJYOTI VERMA\t\t\t\t\t\n\n\n\n3 years of Ex...         NaN
# 45  \n\nMooraboyina Guravaiah\nWorkday Integration...         NaN
# 46  VENKATA SAIKRISHNA\n Workday Consultant\n\n\nP...         NaN
# 47  Rahul  (Techno Functional Consultant)  \nProfe...         NaN
# 48  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...         NaN
# 49  Seeking suitable positions in Workday HCM  as ...         NaN
# 50  \nWORKDAY | HCM | FCM\nName \t\t: Kumar S.S\nR...         NaN
# 51                                                ...         NaN
#
#              Category2      Category3 Category4            Category
# 0                  NaN            NaN       NaN          PeopleSoft
# 1                  NaN            NaN       NaN          PeopleSoft
# 2                  NaN            NaN       NaN          PeopleSoft
# 3                  NaN            NaN       NaN          PeopleSoft
# 4                  NaN            NaN       NaN          PeopleSoft
# 5                  NaN            NaN       NaN          PeopleSoft
# 6                  NaN            NaN       NaN          PeopleSoft
# 7                  NaN            NaN       NaN          PeopleSoft
# 8                  NaN            NaN       NaN          PeopleSoft
# 9                  NaN            NaN       NaN          PeopleSoft
# 10  React JS Developer            NaN       NaN  React JS Developer
# 11  React JS Developer            NaN       NaN  React JS Developer
# 12  React JS Developer            NaN       NaN  React JS Developer
# 13  React JS Developer            NaN       NaN  React JS Developer
# 14  React JS Developer            NaN       NaN  React JS Developer
# 15  React JS Developer            NaN       NaN  React JS Developer
# 16  React JS Developer            NaN       NaN  React JS Developer
# 17  React JS Developer            NaN       NaN  React JS Developer
# 18  React JS Developer            NaN       NaN  React JS Developer
# 19  React JS Developer            NaN       NaN  React JS Developer
# 20  React JS Developer            NaN       NaN  React JS Developer
# 21  React JS Developer            NaN       NaN  React JS Developer
# 22  React JS Developer            NaN       NaN  React JS Developer
# 23  React JS Developer            NaN       NaN  React JS Developer
# 24  React JS Developer            NaN       NaN  React JS Developer
# 25  React JS Developer            NaN       NaN  React JS Developer
# 26  React JS Developer            NaN       NaN  React JS Developer
# 27  React JS Developer            NaN       NaN  React JS Developer
# 28  React JS Developer            NaN       NaN  React JS Developer
# 29  React JS Developer            NaN       NaN  React JS Developer
# 30                 NaN  SQL Developer       NaN       SQL Developer
# 31                 NaN  SQL Developer       NaN       SQL Developer
# 32                 NaN  SQL Developer       NaN       SQL Developer
# 33                 NaN  SQL Developer       NaN       SQL Developer
# 34                 NaN  SQL Developer       NaN       SQL Developer
# 35                 NaN  SQL Developer       NaN       SQL Developer
# 36                 NaN  SQL Developer       NaN       SQL Developer
# 37                 NaN  SQL Developer       NaN       SQL Developer
# 38                 NaN  SQL Developer       NaN       SQL Developer
# 39                 NaN  SQL Developer       NaN       SQL Developer
# 40                 NaN  SQL Developer       NaN       SQL Developer
# 41                 NaN            NaN   Workday             Workday
# 42                 NaN            NaN   Workday             Workday
# 43                 NaN            NaN   Workday             Workday
# 44                 NaN            NaN   Workday             Workday
# 45                 NaN            NaN   Workday             Workday
# 46                 NaN            NaN   Workday             Workday
# 47                 NaN            NaN   Workday             Workday
# 48                 NaN            NaN   Workday             Workday
# 49                 NaN            NaN   Workday             Workday
# 50                 NaN            NaN   Workday             Workday
# 51                 NaN            NaN   Workday             Workday

# %%
resume_data.head(15)
# Out:
#                                           Raw_Details   Category1  \
# 0     Anubhav Kumar Singh\t\t\n\n  To work in a gl...  PeopleSoft
# 1   Murali\n\nExperience Summary \n\nI have 6 year...  PeopleSoft
# 2   \n\n\n\n\n\n\n\n\n\n\n\n\n\nPROFILE SUMMARY\n\...  PeopleSoft
# 3    PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...  PeopleSoft
# 4   PeopleSoft Administration\n \nVivekanand Sayan...  PeopleSoft
# 5   \nHaving 4.6 years of experience in PeopleSoft...  PeopleSoft
# 6   \nHaving 4.6 years of experience in PeopleSoft...  PeopleSoft
# 7    \n\nCAREER OBJECTIVE\t\t\n\nPursuing Peopleso...  PeopleSoft
# 8   Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...  PeopleSoft
# 9   \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nC O N ...  PeopleSoft
# 10  Name: Ravali P \n\n                           ...         NaN
# 11    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...         NaN
# 12  Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...         NaN
# 13  HARIPRIYA BATTINA \nExperience as UI Developer...         NaN
# 14  KAMALAKAR REDDY. A \nLinked In: https://www.li...         NaN
#
#              Category2 Category3 Category4            Category
# 0                  NaN       NaN       NaN          PeopleSoft
# 1                  NaN       NaN       NaN          PeopleSoft
# 2                  NaN       NaN       NaN          PeopleSoft
# 3                  NaN       NaN       NaN          PeopleSoft
# 4                  NaN       NaN       NaN          PeopleSoft
# 5                  NaN       NaN       NaN          PeopleSoft
# 6                  NaN       NaN       NaN          PeopleSoft
# 7                  NaN       NaN       NaN          PeopleSoft
# 8                  NaN       NaN       NaN          PeopleSoft
# 9                  NaN       NaN       NaN          PeopleSoft
# 10  React JS Developer       NaN       NaN  React JS Developer
# 11  React JS Developer       NaN       NaN  React JS Developer
# 12  React JS Developer       NaN       NaN  React JS Developer
# 13  React JS Developer       NaN       NaN  React JS Developer
# 14  React JS Developer       NaN       NaN  React JS Developer

# %%
resume_data["Raw_Details"][4]
# Out:
# 'PeopleSoft Administration\n \nVivekanand Sayana                                                                                                                                                                                                           \t\n\nCareer Objective: \n\nWith my valid expertise of 7.5 years in PeopleSoft, I hope to enhance my skill set while adding value to the business, to enable implementation of solutions, which aid the company’s objectives, understanding and anticipating the needs, interests and motivations of the clients and to deliver on time, budget and to quality, delivering value through improving agility, quality and reliability\n\nProfessional Summary:\n\nOver 7.5 years of experience in PeopleSoft implementation, Support, configuration, migrations, maintenance and administration of Application Server Domains, Process Scheduler Servers, Web Server Domains, PeopleTools Upgrades, Application Updates, PUM, SES and Elastic Search. \nExperience in integration activities between various\xa0PeopleSoft\xa0Financials, HRMS, EPM and FSCM environments.\xa0\nExtensively involved in resolving Performance issues.\nExperience in driving Infrastructure Hardware Upgrades, Disaster Recovery Activities.\xa0\nExperience in Health Check for all the PeopleSoft Environments\nExperience in PeopleSoft Database Refreshes from Production to Development and Testing Environments\nExperience in Performance and Tuning of Application Servers, Web Servers\nPerformed 3 full life cycle implementations in PeopleSoft.\nImplemented PeopleSoft Internet Architecture (PIA) on Demo, Test, Development and Production instances.\nExperience in PeopleSoft Implementation on PeopleTools 8.56, FSCM 9.2, Web Logic 12.2.1, Tuxedo 12.2.2 and Oracle 12c R2 on Oracle Enterprise Linux 7 and Windows 2012 R2.\nExperience in PeopleSoft Installations of PeopleTools 8.55, HCM 9.2, WebLogic 12.1.3,\nTuxedo 12.1.3 and People Books 8.55 on Oracle Enterprise Linux 6 and Windows 2012R2\nExperience in PeopleSoft Installations of PeopleTools 8.54, HCM 9.2, Weblogic 12.1.2, Tuxedo 12.1.0 and People books 8.54 on windows 2012 R2 and Oracle Enterprise Linux 6.\nExperience in PeopleSoft Installations of PeopleTools 8.53, FSCM 9.2, Weblogic 10.3.6, Tuxedo 10.3 and People Books 8.53 on windows 2008 R2 and Oracle Enterprise Linux 5.4\nExperience in PeopleSoft Installations of PeopleTools 8.50, HCM 9.1,Weblogic 10.3, Tuxedo 10.3, Oracle 10g R2 and People Books 8.50 on Windows Server 2003 and Oracle Enterprise Linux 5.\nIn depth experience on PeopleSoft Update Manager (PUM) for applying PeopleTools patches, Application Bundles on PeopleTools 8.53, 8.54 and HRMS 9.2 and FSCM 9.2 Applications, Using DPK’s to deploy PUM latest Images and DPK’s to Install, Middle tier, App Tier and PeopleTools.\nIn Depth Experience in Integration Broker Troubleshooting.\nProficiency in creation and configuration and administration of Application Server Domains, Process scheduler Domains, Web Server Domains \nExperience in Reconfiguration of Application Server Domains, Process Scheduler Server Domains and Web Server domains.\nExperience in Project Migrations using Application Designer and Data Migrations using Data Mover\nExperience in generating Pre-compare reports and Post Compare Reports between various environments.\nExperience in setting up client Work Station for developers and testers.\nExperience in resolving developer issues like resetting passwords, locking and unlocking user accounts.\nMaintain the workflow of PeopleSoft users.\nWorked on applying Patches, Bundles and Tax Updates using Change Assistant and PeopleSoft Update Manager (PUM)\nInstalling and Configuring Change Assistant to apply bundles and tax-updates.\nInvolved in setup configuration of Integration Broker in Financials and HCM Applications.\nMaintaining integrity and internal consistency of the database using DDDAUDIT, SYSAUDIT, ALTERAUDIT reports periodically.\nExperience in load balancing of Application server do ...

# %%
resume_data.to_csv('Raw_Resume.csv', index=False)

# %%
resume_data = pd.read_csv("Raw_Resume.csv")
resume_data
# Out:
#                                           Raw_Details   Category1  \
# 0     Anubhav Kumar Singh\t\t\n\n  To work in a gl...  PeopleSoft
# 1   Murali\n\nExperience Summary \n\nI have 6 year...  PeopleSoft
# 2   \n\n\n\n\n\n\n\n\n\n\n\n\n\nPROFILE SUMMARY\n\...  PeopleSoft
# 3    PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...  PeopleSoft
# 4   PeopleSoft Administration\n \nVivekanand Sayan...  PeopleSoft
# 5   \nHaving 4.6 years of experience in PeopleSoft...  PeopleSoft
# 6   \nHaving 4.6 years of experience in PeopleSoft...  PeopleSoft
# 7    \n\nCAREER OBJECTIVE\t\t\n\nPursuing Peopleso...  PeopleSoft
# 8   Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...  PeopleSoft
# 9   \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nC O N ...  PeopleSoft
# 10  Name: Ravali P \n\n                           ...         NaN
# 11    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...         NaN
# 12  Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...         NaN
# 13  HARIPRIYA BATTINA \nExperience as UI Developer...         NaN
# 14  KAMALAKAR REDDY. A \nLinked In: https://www.li...         NaN
# 15  \nNaveen Sadhu\n\n\nTitle: software developer\...         NaN
# 16   \nPRAGNYA PATTNAIK\n \n \n \n Expertise: \n \...         NaN
# 17  \n\n 204,Sri geethika prestige,road number 10...         NaN
# 18  \n\nThirupathamma Balla\n\nSUMMARY:\n\n2.8 yea...         NaN
# 19  \nUi-Developer/ React JS Developer \nNAME: KRI...         NaN
# 20  \nUi-Developer/ React JS Developer \nNAME: KRI...         NaN
# 21  Kotani Durga Prasad\n\n\nObjective:\n\nAspiran...         NaN
# 22  Venkatalakshmi Pedireddy\nSoftware Developer\n...         NaN
# 23  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...         NaN
# 24  MAREEDU LOKESH BABU\nPROFESSIONAL OVERVIEW\n  ...         NaN
# 25  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...         NaN
# 26  MD KHIZARUDDIN RAUF \n \t EXPERIENCE \n     \n...         NaN
# 27  \nPranish Sonone\n\t\n\n\n\n\nCareer summary:\...         NaN
# 28  Ranga Gaganam  \n \n \nHaving 1+ years of succ...         NaN
# 29  SHAIK ABDUL SHARUK   \n2 years’ Experience in ...         NaN
# 30  ANIL KUMAR MADDUKURI  \t\t\nSQL & MSBI Develop...         NaN
# 31  \nAradhana Tripathi\n\nCurrent Location: Gachi...         NaN
# 32  BUDDHA VAMSI                                  ...         NaN
# 33  KAMBALLA PRADEEP                              ...         NaN
# 34   \n                                        Res...         NaN
# 35  SQL DEVELOPER\nName: -   Bandi prem sai\n\n\nW...         NaN
# 36                                         SQL SER...         NaN
# 37   RAJU PAVANA KUMARI\n\n\nProfessional Summary:...         NaN
# 38                                      resume\n\n...         NaN
# 39  Name: Ramesh\n\nCareer Objective: \n          ...         NaN
# 40  B. vinod kumar\n\nOBJECTIVE:\nWilling to work ...         NaN
# 41  Chinna Subbarayudu M\nDOB: 06th March 1994\nNa...         NaN
# 42  \t\n\n\nName         : Gopi Krishna Reddy\n\t\...         NaN
# 43                                        \n      ...         NaN
# 44  \n\nJYOTI VERMA\t\t\t\t\t\n\n\n\n3 years of Ex...         NaN
# 45  \n\nMooraboyina Guravaiah\nWorkday Integration...         NaN
# 46  VENKATA SAIKRISHNA\n Workday Consultant\n\n\nP...         NaN
# 47  Rahul  (Techno Functional Consultant)  \nProfe...         NaN
# 48  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...         NaN
# 49  Seeking suitable positions in Workday HCM  as ...         NaN
# 50  \nWORKDAY | HCM | FCM\nName \t\t: Kumar S.S\nR...         NaN
# 51                                                ...         NaN
#
#              Category2      Category3 Category4            Category
# 0                  NaN            NaN       NaN          PeopleSoft
# 1                  NaN            NaN       NaN          PeopleSoft
# 2                  NaN            NaN       NaN          PeopleSoft
# 3                  NaN            NaN       NaN          PeopleSoft
# 4                  NaN            NaN       NaN          PeopleSoft
# 5                  NaN            NaN       NaN          PeopleSoft
# 6                  NaN            NaN       NaN          PeopleSoft
# 7                  NaN            NaN       NaN          PeopleSoft
# 8                  NaN            NaN       NaN          PeopleSoft
# 9                  NaN            NaN       NaN          PeopleSoft
# 10  React JS Developer            NaN       NaN  React JS Developer
# 11  React JS Developer            NaN       NaN  React JS Developer
# 12  React JS Developer            NaN       NaN  React JS Developer
# 13  React JS Developer            NaN       NaN  React JS Developer
# 14  React JS Developer            NaN       NaN  React JS Developer
# 15  React JS Developer            NaN       NaN  React JS Developer
# 16  React JS Developer            NaN       NaN  React JS Developer
# 17  React JS Developer            NaN       NaN  React JS Developer
# 18  React JS Developer            NaN       NaN  React JS Developer
# 19  React JS Developer            NaN       NaN  React JS Developer
# 20  React JS Developer            NaN       NaN  React JS Developer
# 21  React JS Developer            NaN       NaN  React JS Developer
# 22  React JS Developer            NaN       NaN  React JS Developer
# 23  React JS Developer            NaN       NaN  React JS Developer
# 24  React JS Developer            NaN       NaN  React JS Developer
# 25  React JS Developer            NaN       NaN  React JS Developer
# 26  React JS Developer            NaN       NaN  React JS Developer
# 27  React JS Developer            NaN       NaN  React JS Developer
# 28  React JS Developer            NaN       NaN  React JS Developer
# 29  React JS Developer            NaN       NaN  React JS Developer
# 30                 NaN  SQL Developer       NaN       SQL Developer
# 31                 NaN  SQL Developer       NaN       SQL Developer
# 32                 NaN  SQL Developer       NaN       SQL Developer
# 33                 NaN  SQL Developer       NaN       SQL Developer
# 34                 NaN  SQL Developer       NaN       SQL Developer
# 35                 NaN  SQL Developer       NaN       SQL Developer
# 36                 NaN  SQL Developer       NaN       SQL Developer
# 37                 NaN  SQL Developer       NaN       SQL Developer
# 38                 NaN  SQL Developer       NaN       SQL Developer
# 39                 NaN  SQL Developer       NaN       SQL Developer
# 40                 NaN  SQL Developer       NaN       SQL Developer
# 41                 NaN            NaN   Workday             Workday
# 42                 NaN            NaN   Workday             Workday
# 43                 NaN            NaN   Workday             Workday
# 44                 NaN            NaN   Workday             Workday
# 45                 NaN            NaN   Workday             Workday
# 46                 NaN            NaN   Workday             Workday
# 47                 NaN            NaN   Workday             Workday
# 48                 NaN            NaN   Workday             Workday
# 49                 NaN            NaN   Workday             Workday
# 50                 NaN            NaN   Workday             Workday
# 51                 NaN            NaN   Workday             Workday

# %%
resume_data[resume_data.Category == 'Workday']
# Out:
#                                           Raw_Details Category1 Category2  \
# 41  Chinna Subbarayudu M\nDOB: 06th March 1994\nNa...       NaN       NaN
# 42  \t\n\n\nName         : Gopi Krishna Reddy\n\t\...       NaN       NaN
# 43                                        \n      ...       NaN       NaN
# 44  \n\nJYOTI VERMA\t\t\t\t\t\n\n\n\n3 years of Ex...       NaN       NaN
# 45  \n\nMooraboyina Guravaiah\nWorkday Integration...       NaN       NaN
# 46  VENKATA SAIKRISHNA\n Workday Consultant\n\n\nP...       NaN       NaN
# 47  Rahul  (Techno Functional Consultant)  \nProfe...       NaN       NaN
# 48  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...       NaN       NaN
# 49  Seeking suitable positions in Workday HCM  as ...       NaN       NaN
# 50  \nWORKDAY | HCM | FCM\nName \t\t: Kumar S.S\nR...       NaN       NaN
# 51                                                ...       NaN       NaN
#
#    Category3 Category4 Category
# 41       NaN   Workday  Workday
# 42       NaN   Workday  Workday
# 43       NaN   Workday  Workday
# 44       NaN   Workday  Workday
# 45       NaN   Workday  Workday
# 46       NaN   Workday  Workday
# 47       NaN   Workday  Workday
# 48       NaN   Workday  Workday
# 49       NaN   Workday  Workday
# 50       NaN   Workday  Workday
# 51       NaN   Workday  Workday

# %%
resume_data.isnull().sum()
# Out:
# Raw_Details     0
# Category1      42
# Category2      32
# Category3      41
# Category4      41
# Category        0
# dtype: int64

# %%
resume_data['Word_Count'] = resume_data['Raw_Details'].apply(lambda x: len(str(x).split(" ")))
resume_data[['Raw_Details','Word_Count']].head()
# Out:
#                                          Raw_Details  Word_Count
# 0    Anubhav Kumar Singh\t\t\n\n  To work in a gl...         978
# 1  Murali\n\nExperience Summary \n\nI have 6 year...         494
# 2  \n\n\n\n\n\n\n\n\n\n\n\n\n\nPROFILE SUMMARY\n\...         451
# 3   PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...         881
# 4  PeopleSoft Administration\n \nVivekanand Sayan...        2508

# %%
resume_data['Char_Count'] = resume_data['Raw_Details'].str.len() ## this also includes spaces
resume_data[['Raw_Details','Char_Count']].head()
# Out:
#                                          Raw_Details  Char_Count
# 0    Anubhav Kumar Singh\t\t\n\n  To work in a gl...        7256
# 1  Murali\n\nExperience Summary \n\nI have 6 year...        3981
# 2  \n\n\n\n\n\n\n\n\n\n\n\n\n\nPROFILE SUMMARY\n\...        3646
# 3   PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...        7265
# 4  PeopleSoft Administration\n \nVivekanand Sayan...       15339

# %%
pip install wordcloud
# Out:
# Collecting wordcloudNote: you may need to restart the kernel to use updated packages.
#
#   Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (2.2.0)
# Requirement already satisfied: pillow in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (11.0.0)
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl (301 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4

# %%
import re
import nltk
import spacy
import string
from matplotlib import pyplot as plt

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

from wordcloud import WordCloud, STOPWORDS
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer

import warnings
warnings.filterwarnings('ignore')

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
resume_data['Stopwords'] = resume_data['Raw_Details'].apply(lambda x: len([x for x in x.split() if x in stop]))
resume_data[['Raw_Details','Stopwords']].head()
# Out:
#                                          Raw_Details  Stopwords
# 0    Anubhav Kumar Singh\t\t\n\n  To work in a gl...        187
# 1  Murali\n\nExperience Summary \n\nI have 6 year...        111
# 2  \n\n\n\n\n\n\n\n\n\n\n\n\n\nPROFILE SUMMARY\n\...         86
# 3   PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...        224
# 4  PeopleSoft Administration\n \nVivekanand Sayan...        519

# %%
resume_data['Numerics'] = resume_data['Raw_Details'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
resume_data[['Raw_Details','Numerics']].head()
# Out:
#                                          Raw_Details  Numerics
# 0    Anubhav Kumar Singh\t\t\n\n  To work in a gl...         3
# 1  Murali\n\nExperience Summary \n\nI have 6 year...         1
# 2  \n\n\n\n\n\n\n\n\n\n\n\n\n\nPROFILE SUMMARY\n\...        15
# 3   PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...         3
# 4  PeopleSoft Administration\n \nVivekanand Sayan...        16

# %%
resume_data
# Out:
#                                           Raw_Details   Category1  \
# 0     Anubhav Kumar Singh\t\t\n\n  To work in a gl...  PeopleSoft
# 1   Murali\n\nExperience Summary \n\nI have 6 year...  PeopleSoft
# 2   \n\n\n\n\n\n\n\n\n\n\n\n\n\nPROFILE SUMMARY\n\...  PeopleSoft
# 3    PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...  PeopleSoft
# 4   PeopleSoft Administration\n \nVivekanand Sayan...  PeopleSoft
# 5   \nHaving 4.6 years of experience in PeopleSoft...  PeopleSoft
# 6   \nHaving 4.6 years of experience in PeopleSoft...  PeopleSoft
# 7    \n\nCAREER OBJECTIVE\t\t\n\nPursuing Peopleso...  PeopleSoft
# 8   Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...  PeopleSoft
# 9   \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nC O N ...  PeopleSoft
# 10  Name: Ravali P \n\n                           ...         NaN
# 11    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...         NaN
# 12  Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...         NaN
# 13  HARIPRIYA BATTINA \nExperience as UI Developer...         NaN
# 14  KAMALAKAR REDDY. A \nLinked In: https://www.li...         NaN
# 15  \nNaveen Sadhu\n\n\nTitle: software developer\...         NaN
# 16   \nPRAGNYA PATTNAIK\n \n \n \n Expertise: \n \...         NaN
# 17  \n\n 204,Sri geethika prestige,road number 10...         NaN
# 18  \n\nThirupathamma Balla\n\nSUMMARY:\n\n2.8 yea...         NaN
# 19  \nUi-Developer/ React JS Developer \nNAME: KRI...         NaN
# 20  \nUi-Developer/ React JS Developer \nNAME: KRI...         NaN
# 21  Kotani Durga Prasad\n\n\nObjective:\n\nAspiran...         NaN
# 22  Venkatalakshmi Pedireddy\nSoftware Developer\n...         NaN
# 23  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...         NaN
# 24  MAREEDU LOKESH BABU\nPROFESSIONAL OVERVIEW\n  ...         NaN
# 25  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...         NaN
# 26  MD KHIZARUDDIN RAUF \n \t EXPERIENCE \n     \n...         NaN
# 27  \nPranish Sonone\n\t\n\n\n\n\nCareer summary:\...         NaN
# 28  Ranga Gaganam  \n \n \nHaving 1+ years of succ...         NaN
# 29  SHAIK ABDUL SHARUK   \n2 years’ Experience in ...         NaN
# 30  ANIL KUMAR MADDUKURI  \t\t\nSQL & MSBI Develop...         NaN
# 31  \nAradhana Tripathi\n\nCurrent Location: Gachi...         NaN
# 32  BUDDHA VAMSI                                  ...         NaN
# 33  KAMBALLA PRADEEP                              ...         NaN
# 34   \n                                        Res...         NaN
# 35  SQL DEVELOPER\nName: -   Bandi prem sai\n\n\nW...         NaN
# 36                                         SQL SER...         NaN
# 37   RAJU PAVANA KUMARI\n\n\nProfessional Summary:...         NaN
# 38                                      resume\n\n...         NaN
# 39  Name: Ramesh\n\nCareer Objective: \n          ...         NaN
# 40  B. vinod kumar\n\nOBJECTIVE:\nWilling to work ...         NaN
# 41  Chinna Subbarayudu M\nDOB: 06th March 1994\nNa...         NaN
# 42  \t\n\n\nName         : Gopi Krishna Reddy\n\t\...         NaN
# 43                                        \n      ...         NaN
# 44  \n\nJYOTI VERMA\t\t\t\t\t\n\n\n\n3 years of Ex...         NaN
# 45  \n\nMooraboyina Guravaiah\nWorkday Integration...         NaN
# 46  VENKATA SAIKRISHNA\n Workday Consultant\n\n\nP...         NaN
# 47  Rahul  (Techno Functional Consultant)  \nProfe...         NaN
# 48  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...         NaN
# 49  Seeking suitable positions in Workday HCM  as ...         NaN
# 50  \nWORKDAY | HCM | FCM\nName \t\t: Kumar S.S\nR...         NaN
# 51                                                ...         NaN
#
#              Category2      Category3 Category4            Category  \
# 0                  NaN            NaN       NaN          PeopleSoft
# 1                  NaN            NaN       NaN          PeopleSoft
# 2                  NaN            NaN       NaN          PeopleSoft
# 3                  NaN            NaN       NaN          PeopleSoft
# 4                  NaN            NaN       NaN          PeopleSoft
# 5                  NaN            NaN       NaN          PeopleSoft
# 6                  NaN            NaN       NaN          PeopleSoft
# 7                  NaN            NaN       NaN          PeopleSoft
# 8                  NaN            NaN       NaN          PeopleSoft
# 9                  NaN            NaN       NaN          PeopleSoft
# 10  React JS Developer            NaN       NaN  React JS Developer
# 11  React JS Developer            NaN       NaN  React JS Developer
# 12  React JS Developer            NaN       NaN  React JS Developer
# 13  React JS Developer            NaN       NaN  React JS Developer
# 14  React JS Developer            NaN       NaN  React JS Developer
# 15  React JS Developer            NaN       NaN  React JS Developer
# 16  React JS Developer            NaN       NaN  React JS Developer
# 17  React JS Developer            NaN       NaN  React JS Developer
# 18  React JS Developer            NaN       NaN  React JS Developer
# 19  React JS Developer            NaN       NaN  React JS Developer
# 20  React JS Developer            NaN       NaN  React JS Developer
# 21  React JS Developer            NaN       NaN  React JS Developer
# 22  React JS Developer            NaN       NaN  React JS Developer
# 23  React JS Developer            NaN       NaN  React JS Developer
# 24  React JS Developer            NaN       NaN  React JS Developer
# 25  React JS Developer            NaN       NaN  React JS Developer
# 26  React JS Developer            NaN       NaN  React JS Developer
# 27  React JS Developer            NaN       NaN  React JS Developer
# 28  React JS Developer            NaN       NaN  React JS Developer
# 29  React JS Developer            NaN       NaN  React JS Developer
# 30                 NaN  SQL Developer       NaN       SQL Developer
# 31                 NaN  SQL Developer       NaN       SQL Developer
# 32                 NaN  SQL Developer       NaN       SQL Developer
# 33                 NaN  SQL Developer       NaN       SQL Developer
# 34                 NaN  SQL Developer       NaN       SQL Developer
# 35                 NaN  SQL Developer       NaN       SQL Developer
# 36                 NaN  SQL Developer       NaN       SQL Developer
# 37                 NaN  SQL Developer       NaN       SQL Developer
# 38                 NaN  SQL Developer       NaN       SQL Developer
# 39                 NaN  SQL Developer       NaN       SQL Developer
# 40                 NaN  SQL Developer       NaN       SQL Developer
# 41                 NaN            NaN   Workday             Workday
# 42                 NaN            NaN   Workday             Workday
# 43                 NaN            NaN   Workday             Workday
# 44                 NaN            NaN   Workday             Workday
# 45                 NaN            NaN   Workday             Workday
# 46                 NaN            NaN   Workday             Workday
# 47                 NaN            NaN   Workday             Workday
# 48                 NaN            NaN   Workday             Workday
# 49                 NaN            NaN   Workday             Workday
# 50                 NaN            NaN   Workday             Workday
# 51                 NaN            NaN   Workday             Workday
#
#     Word_Count  Char_Count  Stopwords  Numerics
# 0          978        7256        187         3
# 1          494        3981        111         1
# 2          451        3646         86        15
# 3          881        7265        224         3
# 4         2508       15339        519        16
# 5          364        2950         81         3
# 6          358        2920         77         3
# 7          540        3481        136         3
# 8          363        2732         98         4
# 9          356        2112         42         8
# 10        1536        3498         58         4
# 11         490        1667         38         0
# 12         502        3547        134         3
# 13         404        2627        106         6
# 14         357        2621         48         8
# 15         239        1450         58         1
# 16         443        2609         86         2
# 17         317        2542         93         5
# 18         115         994         32         0
# 19         361        3633        112         2
# 20         361        3634        112         2
# 21         719        5383        216         2
# 22         256        2120         43         1
# 23         333        1568         41         7
# 24         945        2912         67         4
# 25         945        2913         67         4
# 26         778        3172         70         5
# 27         192        1548         50         5
# 28         234        1625         52         0
# 29         284        1440         47         1
# 30         645        4377        124         3
# 31         664        5089        146         6
# 32         296        1693         36         7
# 33         336        1917         61         1
# 34        1144        4826        151         8
# 35         580        3971        126         1
# 36         592        3651        116         4
# 37         577        3959        134         2
# 38         745        4085        154         4
# 39        1074        6579        194         5
# 40         526        3999        138         3
# 41         917        6010        215         4
# 42         640        4289        125         1
# 43        1408        5317        156         2
# 44         427        3533        110         3
# 45        1210        6785        214         1
# 46         493        3930        100         1
# 47        1268        8655        340         7
# 48         687        5381        156         1
# 49         990        6324        191         6
# 50         979        7309        228         1
# 51         776        5089        150         2

# %%
def preprocess(sentence):
    sentence = str(sentence)
    sentence = sentence.lower()
    sentence = sentence.replace('{html}',"") 
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', sentence)
    rem_url = re.sub(r'http\S+', '',cleantext)
    rem_num = re.sub('[0-9]+', '', rem_url)
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(rem_num)  
    filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')]

    return " ".join(filtered_words)

# %%
resume_data = pd.read_csv('Raw_Resume.csv')
resume_data['Resume_Details'] = resume_data.Raw_Details.apply(lambda x: preprocess(x))

# %%
resume_data
# Out:
#                                           Raw_Details   Category1  \
# 0     Anubhav Kumar Singh\t\t\n\n  To work in a gl...  PeopleSoft
# 1   Murali\n\nExperience Summary \n\nI have 6 year...  PeopleSoft
# 2   \n\n\n\n\n\n\n\n\n\n\n\n\n\nPROFILE SUMMARY\n\...  PeopleSoft
# 3    PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...  PeopleSoft
# 4   PeopleSoft Administration\n \nVivekanand Sayan...  PeopleSoft
# 5   \nHaving 4.6 years of experience in PeopleSoft...  PeopleSoft
# 6   \nHaving 4.6 years of experience in PeopleSoft...  PeopleSoft
# 7    \n\nCAREER OBJECTIVE\t\t\n\nPursuing Peopleso...  PeopleSoft
# 8   Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...  PeopleSoft
# 9   \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nC O N ...  PeopleSoft
# 10  Name: Ravali P \n\n                           ...         NaN
# 11    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...         NaN
# 12  Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...         NaN
# 13  HARIPRIYA BATTINA \nExperience as UI Developer...         NaN
# 14  KAMALAKAR REDDY. A \nLinked In: https://www.li...         NaN
# 15  \nNaveen Sadhu\n\n\nTitle: software developer\...         NaN
# 16   \nPRAGNYA PATTNAIK\n \n \n \n Expertise: \n \...         NaN
# 17  \n\n 204,Sri geethika prestige,road number 10...         NaN
# 18  \n\nThirupathamma Balla\n\nSUMMARY:\n\n2.8 yea...         NaN
# 19  \nUi-Developer/ React JS Developer \nNAME: KRI...         NaN
# 20  \nUi-Developer/ React JS Developer \nNAME: KRI...         NaN
# 21  Kotani Durga Prasad\n\n\nObjective:\n\nAspiran...         NaN
# 22  Venkatalakshmi Pedireddy\nSoftware Developer\n...         NaN
# 23  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...         NaN
# 24  MAREEDU LOKESH BABU\nPROFESSIONAL OVERVIEW\n  ...         NaN
# 25  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...         NaN
# 26  MD KHIZARUDDIN RAUF \n \t EXPERIENCE \n     \n...         NaN
# 27  \nPranish Sonone\n\t\n\n\n\n\nCareer summary:\...         NaN
# 28  Ranga Gaganam  \n \n \nHaving 1+ years of succ...         NaN
# 29  SHAIK ABDUL SHARUK   \n2 years’ Experience in ...         NaN
# 30  ANIL KUMAR MADDUKURI  \t\t\nSQL & MSBI Develop...         NaN
# 31  \nAradhana Tripathi\n\nCurrent Location: Gachi...         NaN
# 32  BUDDHA VAMSI                                  ...         NaN
# 33  KAMBALLA PRADEEP                              ...         NaN
# 34   \n                                        Res...         NaN
# 35  SQL DEVELOPER\nName: -   Bandi prem sai\n\n\nW...         NaN
# 36                                         SQL SER...         NaN
# 37   RAJU PAVANA KUMARI\n\n\nProfessional Summary:...         NaN
# 38                                      resume\n\n...         NaN
# 39  Name: Ramesh\n\nCareer Objective: \n          ...         NaN
# 40  B. vinod kumar\n\nOBJECTIVE:\nWilling to work ...         NaN
# 41  Chinna Subbarayudu M\nDOB: 06th March 1994\nNa...         NaN
# 42  \t\n\n\nName         : Gopi Krishna Reddy\n\t\...         NaN
# 43                                        \n      ...         NaN
# 44  \n\nJYOTI VERMA\t\t\t\t\t\n\n\n\n3 years of Ex...         NaN
# 45  \n\nMooraboyina Guravaiah\nWorkday Integration...         NaN
# 46  VENKATA SAIKRISHNA\n Workday Consultant\n\n\nP...         NaN
# 47  Rahul  (Techno Functional Consultant)  \nProfe...         NaN
# 48  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...         NaN
# 49  Seeking suitable positions in Workday HCM  as ...         NaN
# 50  \nWORKDAY | HCM | FCM\nName \t\t: Kumar S.S\nR...         NaN
# 51                                                ...         NaN
#
#              Category2      Category3 Category4            Category  \
# 0                  NaN            NaN       NaN          PeopleSoft
# 1                  NaN            NaN       NaN          PeopleSoft
# 2                  NaN            NaN       NaN          PeopleSoft
# 3                  NaN            NaN       NaN          PeopleSoft
# 4                  NaN            NaN       NaN          PeopleSoft
# 5                  NaN            NaN       NaN          PeopleSoft
# 6                  NaN            NaN       NaN          PeopleSoft
# 7                  NaN            NaN       NaN          PeopleSoft
# 8                  NaN            NaN       NaN          PeopleSoft
# 9                  NaN            NaN       NaN          PeopleSoft
# 10  React JS Developer            NaN       NaN  React JS Developer
# 11  React JS Developer            NaN       NaN  React JS Developer
# 12  React JS Developer            NaN       NaN  React JS Developer
# 13  React JS Developer            NaN       NaN  React JS Developer
# 14  React JS Developer            NaN       NaN  React JS Developer
# 15  React JS Developer            NaN       NaN  React JS Developer
# 16  React JS Developer            NaN       NaN  React JS Developer
# 17  React JS Developer            NaN       NaN  React JS Developer
# 18  React JS Developer            NaN       NaN  React JS Developer
# 19  React JS Developer            NaN       NaN  React JS Developer
# 20  React JS Developer            NaN       NaN  React JS Developer
# 21  React JS Developer            NaN       NaN  React JS Developer
# 22  React JS Developer            NaN       NaN  React JS Developer
# 23  React JS Developer            NaN       NaN  React JS Developer
# 24  React JS Developer            NaN       NaN  React JS Developer
# 25  React JS Developer            NaN       NaN  React JS Developer
# 26  React JS Developer            NaN       NaN  React JS Developer
# 27  React JS Developer            NaN       NaN  React JS Developer
# 28  React JS Developer            NaN       NaN  React JS Developer
# 29  React JS Developer            NaN       NaN  React JS Developer
# 30                 NaN  SQL Developer       NaN       SQL Developer
# 31                 NaN  SQL Developer       NaN       SQL Developer
# 32                 NaN  SQL Developer       NaN       SQL Developer
# 33                 NaN  SQL Developer       NaN       SQL Developer
# 34                 NaN  SQL Developer       NaN       SQL Developer
# 35                 NaN  SQL Developer       NaN       SQL Developer
# 36                 NaN  SQL Developer       NaN       SQL Developer
# 37                 NaN  SQL Developer       NaN       SQL Developer
# 38                 NaN  SQL Developer       NaN       SQL Developer
# 39                 NaN  SQL Developer       NaN       SQL Developer
# 40                 NaN  SQL Developer       NaN       SQL Developer
# 41                 NaN            NaN   Workday             Workday
# 42                 NaN            NaN   Workday             Workday
# 43                 NaN            NaN   Workday             Workday
# 44                 NaN            NaN   Workday             Workday
# 45                 NaN            NaN   Workday             Workday
# 46                 NaN            NaN   Workday             Workday
# 47                 NaN            NaN   Workday             Workday
# 48                 NaN            NaN   Workday             Workday
# 49                 NaN            NaN   Workday             Workday
# 50                 NaN            NaN   Workday             Workday
# 51                 NaN            NaN   Workday             Workday
#
#                                        Resume_Details
# 0   anubhav kumar singh work globally competitive ...
# 1   murali experience summary years experience wor...
# 2   profile summary overall years experience peopl...
# 3   peoplesoft admin varkala vikas career objectiv...
# 4   peoplesoft administration vivekanand sayana ca...
# 5   years experience peoplesoft application enhanc...
# 6   years experience peoplesoft application enhanc...
# 7   career objective pursuing peoplesoft executive...
# 8   tanna sujatha objective seeking challenging ro...
# 9   address manyata tech park nagavara bangalore l...
# 10  name ravali curriculum vitae specialization co...
# 11  susovan bag seeking challenging position field...
# 12  kanumuru deepak reddy career objective secure ...
# 13  haripriya battina experience developer reactjs...
# 14  kamalakar reddy linked professional summary ye...
# 15  naveen sadhu title software developer location...
# 16  pragnya pattnaik expertise around years experi...
# 17  sri geethika prestige road number bandari layo...
# 18  thirupathamma balla summary year experience re...
# 19  developer react developer name krishna profess...
# 20  developer react developer name krishna profess...
# 21  kotani durga prasad objective aspirant positio...
# 22  venkatalakshmi pedireddy software developer ex...
# 23  kambala sai surendra mandepeta summary project...
# 24  mareedu lokesh babu professional overview arou...
# 25  mareedu lokesh babu professional overview arou...
# 26  khizaruddin rauf experience currently working ...
# 27  pranish sonone career summary experience years...
# 28  ranga gaganam years successful experience phas...
# 29  shaik abdul sharuk years experience wipro care...
# 30  anil kumar maddukuri sql msbi developer summar...
# 31  aradhana tripathi current location gachibowli ...
# 32  buddha vamsi career objective years experience...
# 33  kamballa pradeep synopsis looking forward aspi...
# 34  resume name neeraj mishra year month experienc...
# 35  sql developer name bandi prem sai willing work...
# 36  sql server developer syam kumar professional s...
# 37  raju pavana kumari professional summary years ...
# 38  resume ramalakshmi career objective profession...
# 39  name ramesh career objective contribute organi...
# 40  vinod kumar objective willing work challenging...
# 41  chinna subbarayudu dob march nationality india...
# 42  name gopi krishna reddy professional summery w...
# 43  himaja career objective work towards achieving...
# 44  jyoti verma years experience workday functiona...
# 45  mooraboyina guravaiah workday integration spec...
# 46  venkata saikrishna workday consultant profssio...
# 47  rahul techno functional consultant professiona...
# 48  ramesh workday hcm consultant professional sum...
# 49  seeking suitable positions workday hcm techno ...
# 50  workday hcm fcm name kumar role workday consul...
# 51  vinay kumar workday functional consultant expe...

# %%
resume_data.drop(['Raw_Details'], axis = 1, inplace = True)
resume_data
# Out:
#      Category1           Category2      Category3 Category4  \
# 0   PeopleSoft                 NaN            NaN       NaN
# 1   PeopleSoft                 NaN            NaN       NaN
# 2   PeopleSoft                 NaN            NaN       NaN
# 3   PeopleSoft                 NaN            NaN       NaN
# 4   PeopleSoft                 NaN            NaN       NaN
# 5   PeopleSoft                 NaN            NaN       NaN
# 6   PeopleSoft                 NaN            NaN       NaN
# 7   PeopleSoft                 NaN            NaN       NaN
# 8   PeopleSoft                 NaN            NaN       NaN
# 9   PeopleSoft                 NaN            NaN       NaN
# 10         NaN  React JS Developer            NaN       NaN
# 11         NaN  React JS Developer            NaN       NaN
# 12         NaN  React JS Developer            NaN       NaN
# 13         NaN  React JS Developer            NaN       NaN
# 14         NaN  React JS Developer            NaN       NaN
# 15         NaN  React JS Developer            NaN       NaN
# 16         NaN  React JS Developer            NaN       NaN
# 17         NaN  React JS Developer            NaN       NaN
# 18         NaN  React JS Developer            NaN       NaN
# 19         NaN  React JS Developer            NaN       NaN
# 20         NaN  React JS Developer            NaN       NaN
# 21         NaN  React JS Developer            NaN       NaN
# 22         NaN  React JS Developer            NaN       NaN
# 23         NaN  React JS Developer            NaN       NaN
# 24         NaN  React JS Developer            NaN       NaN
# 25         NaN  React JS Developer            NaN       NaN
# 26         NaN  React JS Developer            NaN       NaN
# 27         NaN  React JS Developer            NaN       NaN
# 28         NaN  React JS Developer            NaN       NaN
# 29         NaN  React JS Developer            NaN       NaN
# 30         NaN                 NaN  SQL Developer       NaN
# 31         NaN                 NaN  SQL Developer       NaN
# 32         NaN                 NaN  SQL Developer       NaN
# 33         NaN                 NaN  SQL Developer       NaN
# 34         NaN                 NaN  SQL Developer       NaN
# 35         NaN                 NaN  SQL Developer       NaN
# 36         NaN                 NaN  SQL Developer       NaN
# 37         NaN                 NaN  SQL Developer       NaN
# 38         NaN                 NaN  SQL Developer       NaN
# 39         NaN                 NaN  SQL Developer       NaN
# 40         NaN                 NaN  SQL Developer       NaN
# 41         NaN                 NaN            NaN   Workday
# 42         NaN                 NaN            NaN   Workday
# 43         NaN                 NaN            NaN   Workday
# 44         NaN                 NaN            NaN   Workday
# 45         NaN                 NaN            NaN   Workday
# 46         NaN                 NaN            NaN   Workday
# 47         NaN                 NaN            NaN   Workday
# 48         NaN                 NaN            NaN   Workday
# 49         NaN                 NaN            NaN   Workday
# 50         NaN                 NaN            NaN   Workday
# 51         NaN                 NaN            NaN   Workday
#
#               Category                                     Resume_Details
# 0           PeopleSoft  anubhav kumar singh work globally competitive ...
# 1           PeopleSoft  murali experience summary years experience wor...
# 2           PeopleSoft  profile summary overall years experience peopl...
# 3           PeopleSoft  peoplesoft admin varkala vikas career objectiv...
# 4           PeopleSoft  peoplesoft administration vivekanand sayana ca...
# 5           PeopleSoft  years experience peoplesoft application enhanc...
# 6           PeopleSoft  years experience peoplesoft application enhanc...
# 7           PeopleSoft  career objective pursuing peoplesoft executive...
# 8           PeopleSoft  tanna sujatha objective seeking challenging ro...
# 9           PeopleSoft  address manyata tech park nagavara bangalore l...
# 10  React JS Developer  name ravali curriculum vitae specialization co...
# 11  React JS Developer  susovan bag seeking challenging position field...
# 12  React JS Developer  kanumuru deepak reddy career objective secure ...
# 13  React JS Developer  haripriya battina experience developer reactjs...
# 14  React JS Developer  kamalakar reddy linked professional summary ye...
# 15  React JS Developer  naveen sadhu title software developer location...
# 16  React JS Developer  pragnya pattnaik expertise around years experi...
# 17  React JS Developer  sri geethika prestige road number bandari layo...
# 18  React JS Developer  thirupathamma balla summary year experience re...
# 19  React JS Developer  developer react developer name krishna profess...
# 20  React JS Developer  developer react developer name krishna profess...
# 21  React JS Developer  kotani durga prasad objective aspirant positio...
# 22  React JS Developer  venkatalakshmi pedireddy software developer ex...
# 23  React JS Developer  kambala sai surendra mandepeta summary project...
# 24  React JS Developer  mareedu lokesh babu professional overview arou...
# 25  React JS Developer  mareedu lokesh babu professional overview arou...
# 26  React JS Developer  khizaruddin rauf experience currently working ...
# 27  React JS Developer  pranish sonone career summary experience years...
# 28  React JS Developer  ranga gaganam years successful experience phas...
# 29  React JS Developer  shaik abdul sharuk years experience wipro care...
# 30       SQL Developer  anil kumar maddukuri sql msbi developer summar...
# 31       SQL Developer  aradhana tripathi current location gachibowli ...
# 32       SQL Developer  buddha vamsi career objective years experience...
# 33       SQL Developer  kamballa pradeep synopsis looking forward aspi...
# 34       SQL Developer  resume name neeraj mishra year month experienc...
# 35       SQL Developer  sql developer name bandi prem sai willing work...
# 36       SQL Developer  sql server developer syam kumar professional s...
# 37       SQL Developer  raju pavana kumari professional summary years ...
# 38       SQL Developer  resume ramalakshmi career objective profession...
# 39       SQL Developer  name ramesh career objective contribute organi...
# 40       SQL Developer  vinod kumar objective willing work challenging...
# 41             Workday  chinna subbarayudu dob march nationality india...
# 42             Workday  name gopi krishna reddy professional summery w...
# 43             Workday  himaja career objective work towards achieving...
# 44             Workday  jyoti verma years experience workday functiona...
# 45             Workday  mooraboyina guravaiah workday integration spec...
# 46             Workday  venkata saikrishna workday consultant profssio...
# 47             Workday  rahul techno functional consultant professiona...
# 48             Workday  ramesh workday hcm consultant professional sum...
# 49             Workday  seeking suitable positions workday hcm techno ...
# 50             Workday  workday hcm fcm name kumar role workday consul...
# 51             Workday  vinay kumar workday functional consultant expe...

# %%
resume_data.to_csv('Cleaned_Resumes.csv', index = False)

# %%
resume_data = pd.read_csv('Cleaned_Resumes.csv')
resume_data
# Out:
#      Category1           Category2      Category3 Category4  \
# 0   PeopleSoft                 NaN            NaN       NaN
# 1   PeopleSoft                 NaN            NaN       NaN
# 2   PeopleSoft                 NaN            NaN       NaN
# 3   PeopleSoft                 NaN            NaN       NaN
# 4   PeopleSoft                 NaN            NaN       NaN
# 5   PeopleSoft                 NaN            NaN       NaN
# 6   PeopleSoft                 NaN            NaN       NaN
# 7   PeopleSoft                 NaN            NaN       NaN
# 8   PeopleSoft                 NaN            NaN       NaN
# 9   PeopleSoft                 NaN            NaN       NaN
# 10         NaN  React JS Developer            NaN       NaN
# 11         NaN  React JS Developer            NaN       NaN
# 12         NaN  React JS Developer            NaN       NaN
# 13         NaN  React JS Developer            NaN       NaN
# 14         NaN  React JS Developer            NaN       NaN
# 15         NaN  React JS Developer            NaN       NaN
# 16         NaN  React JS Developer            NaN       NaN
# 17         NaN  React JS Developer            NaN       NaN
# 18         NaN  React JS Developer            NaN       NaN
# 19         NaN  React JS Developer            NaN       NaN
# 20         NaN  React JS Developer            NaN       NaN
# 21         NaN  React JS Developer            NaN       NaN
# 22         NaN  React JS Developer            NaN       NaN
# 23         NaN  React JS Developer            NaN       NaN
# 24         NaN  React JS Developer            NaN       NaN
# 25         NaN  React JS Developer            NaN       NaN
# 26         NaN  React JS Developer            NaN       NaN
# 27         NaN  React JS Developer            NaN       NaN
# 28         NaN  React JS Developer            NaN       NaN
# 29         NaN  React JS Developer            NaN       NaN
# 30         NaN                 NaN  SQL Developer       NaN
# 31         NaN                 NaN  SQL Developer       NaN
# 32         NaN                 NaN  SQL Developer       NaN
# 33         NaN                 NaN  SQL Developer       NaN
# 34         NaN                 NaN  SQL Developer       NaN
# 35         NaN                 NaN  SQL Developer       NaN
# 36         NaN                 NaN  SQL Developer       NaN
# 37         NaN                 NaN  SQL Developer       NaN
# 38         NaN                 NaN  SQL Developer       NaN
# 39         NaN                 NaN  SQL Developer       NaN
# 40         NaN                 NaN  SQL Developer       NaN
# 41         NaN                 NaN            NaN   Workday
# 42         NaN                 NaN            NaN   Workday
# 43         NaN                 NaN            NaN   Workday
# 44         NaN                 NaN            NaN   Workday
# 45         NaN                 NaN            NaN   Workday
# 46         NaN                 NaN            NaN   Workday
# 47         NaN                 NaN            NaN   Workday
# 48         NaN                 NaN            NaN   Workday
# 49         NaN                 NaN            NaN   Workday
# 50         NaN                 NaN            NaN   Workday
# 51         NaN                 NaN            NaN   Workday
#
#               Category                                     Resume_Details
# 0           PeopleSoft  anubhav kumar singh work globally competitive ...
# 1           PeopleSoft  murali experience summary years experience wor...
# 2           PeopleSoft  profile summary overall years experience peopl...
# 3           PeopleSoft  peoplesoft admin varkala vikas career objectiv...
# 4           PeopleSoft  peoplesoft administration vivekanand sayana ca...
# 5           PeopleSoft  years experience peoplesoft application enhanc...
# 6           PeopleSoft  years experience peoplesoft application enhanc...
# 7           PeopleSoft  career objective pursuing peoplesoft executive...
# 8           PeopleSoft  tanna sujatha objective seeking challenging ro...
# 9           PeopleSoft  address manyata tech park nagavara bangalore l...
# 10  React JS Developer  name ravali curriculum vitae specialization co...
# 11  React JS Developer  susovan bag seeking challenging position field...
# 12  React JS Developer  kanumuru deepak reddy career objective secure ...
# 13  React JS Developer  haripriya battina experience developer reactjs...
# 14  React JS Developer  kamalakar reddy linked professional summary ye...
# 15  React JS Developer  naveen sadhu title software developer location...
# 16  React JS Developer  pragnya pattnaik expertise around years experi...
# 17  React JS Developer  sri geethika prestige road number bandari layo...
# 18  React JS Developer  thirupathamma balla summary year experience re...
# 19  React JS Developer  developer react developer name krishna profess...
# 20  React JS Developer  developer react developer name krishna profess...
# 21  React JS Developer  kotani durga prasad objective aspirant positio...
# 22  React JS Developer  venkatalakshmi pedireddy software developer ex...
# 23  React JS Developer  kambala sai surendra mandepeta summary project...
# 24  React JS Developer  mareedu lokesh babu professional overview arou...
# 25  React JS Developer  mareedu lokesh babu professional overview arou...
# 26  React JS Developer  khizaruddin rauf experience currently working ...
# 27  React JS Developer  pranish sonone career summary experience years...
# 28  React JS Developer  ranga gaganam years successful experience phas...
# 29  React JS Developer  shaik abdul sharuk years experience wipro care...
# 30       SQL Developer  anil kumar maddukuri sql msbi developer summar...
# 31       SQL Developer  aradhana tripathi current location gachibowli ...
# 32       SQL Developer  buddha vamsi career objective years experience...
# 33       SQL Developer  kamballa pradeep synopsis looking forward aspi...
# 34       SQL Developer  resume name neeraj mishra year month experienc...
# 35       SQL Developer  sql developer name bandi prem sai willing work...
# 36       SQL Developer  sql server developer syam kumar professional s...
# 37       SQL Developer  raju pavana kumari professional summary years ...
# 38       SQL Developer  resume ramalakshmi career objective profession...
# 39       SQL Developer  name ramesh career objective contribute organi...
# 40       SQL Developer  vinod kumar objective willing work challenging...
# 41             Workday  chinna subbarayudu dob march nationality india...
# 42             Workday  name gopi krishna reddy professional summery w...
# 43             Workday  himaja career objective work towards achieving...
# 44             Workday  jyoti verma years experience workday functiona...
# 45             Workday  mooraboyina guravaiah workday integration spec...
# 46             Workday  venkata saikrishna workday consultant profssio...
# 47             Workday  rahul techno functional consultant professiona...
# 48             Workday  ramesh workday hcm consultant professional sum...
# 49             Workday  seeking suitable positions workday hcm techno ...
# 50             Workday  workday hcm fcm name kumar role workday consul...
# 51             Workday  vinay kumar workday functional consultant expe...

# %%
resume_data.Resume_Details[5]
# Out:
# 'years experience peoplesoft application enhancement implementation data conversion support upgrade projects well experienced people tools functional knowledge hcm fscm applications bachelor technology tech jntu currently working people soft consultant randstad hyderabad peoplesoft consultant randstad hyderabad andhra pradesh india june till date project randstad enhancements client randstad staffing responsibilities analyze requirement documents understand customer business requirement provide technical approach fdd assign customize system applications designed many objects scratch write people code implement business logic design custom application engine programs process data design application engine programs send notifications responsible prepare unit test cases technical design documents responsible support sit uat environment people tools application designer application engine people code component interface application packages peoplesoft hcm oracle windows technical associate verizon hyderabad andhra pradesh india dec may project verizon wireless development client verizon responsibilities analyze requirement documents understand customer business requirement provide technical approach fdd assign customize system applications designed many objects scratch write people code implement business logic design custom application engine programs process data design application engine programs send notifications implemented component interface program load data people soft used file layout inbound programs responsible prepare unit test cases technical design documents responsible support sit uat environment people tools application designer application engine people code component interface application packages peoplesoft fscm oracle windows software engineer hsbc hyderabad india aug nov project hsbc upgrade project client hsbc bank responsibilities analysis understand source target system business process compare objects source targets identify changes retrofit objects based compare reports unit testing prepare unit test cases retrofit design development new modifications required customer prepared technical design documents retrofit enhancement add new text catalogues various languages responsible overseeing quality procedures related project responsible move objects development sit environment environment people tools application designer application engine people code peoplesoft hcm windows unix'

# %% [markdown]
# # Named Entity Recognition (NER)

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
oneSetOfStopWords = set(stopwords.words('english')+['``',"''"])
totalWords =[]
Sentences = resume_data['Resume_Details'].values
cleanedSentences = ""
for records in Sentences:
    cleanedText = preprocess(records)
    cleanedSentences += cleanedText
    requiredWords = nltk.word_tokenize(cleanedText)
    for word in requiredWords:
        if word not in oneSetOfStopWords and word not in string.punctuation:
            totalWords.append(word)
    
wordfreqdist = nltk.FreqDist(totalWords)
mostcommon = wordfreqdist.most_common(50)
print(mostcommon)
# Out:
# [('experience', 309), ('using', 241), ('workday', 194), ('application', 186), ('sql', 178), ('project', 168), ('server', 168), ('data', 167), ('reports', 164), ('peoplesoft', 156), ('business', 156), ('knowledge', 129), ('web', 125), ('process', 120), ('react', 116), ('good', 103), ('skills', 100), ('system', 96), ('involved', 96), ('working', 96), ('various', 95), ('creating', 94), ('client', 94), ('like', 93), ('worked', 92), ('support', 91), ('integrations', 90), ('development', 88), ('database', 86), ('tools', 84), ('technical', 84), ('servers', 83), ('integration', 81), ('hcm', 78), ('developer', 78), ('design', 76), ('created', 75), ('used', 74), ('report', 74), ('people', 71), ('work', 70), ('testing', 69), ('responsibilities', 68), ('html', 68), ('team', 67), ('services', 67), ('new', 66), ('custom', 66), ('user', 64), ('developed', 63)]

# %%
pip install -U spacy
# Out:
# Requirement already satisfied: spacy in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (3.8.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (8.3.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.2.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.10.3)
# Requirement already satisfied: jinja2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (75.6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<1.1.0,>=1.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy) (1.0.2)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy) (0.1.5)
# Collecting numpy>=1.19.0 (from spacy)
#   Downloading numpy-2.0.2-cp312-cp312-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Downloading numpy-2.0.2-cp312-cp312-win_amd64.whl (15.6 MB)
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/15.6 MB 6.7 MB/s eta 0:00:03
#    -------- ------------------------------- 3.4/15.6 MB 15.5 MB/s eta 0:00:01
#    ------------ --------------------------- 5.0/15.6 MB 10.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.3/15.6 MB 8.8 MB/s eta 0:00:02
#    ------------------ --------------------- 7.1/15.6 MB 7.8 MB/s eta 0:00:02
#    -------------------- ------------------- 8.1/15.6 MB 7.2 MB/s eta 0:00:02
#    ------------------------ --------------- 9.4/15.6 MB 7.0 MB/s eta 0:00:01
#    -------------------------- ------------- 10.2/15.6 MB 6.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.0/15.6 MB 6.3 MB/s eta 0:00:01
#    ------------------------------ --------- 11.8/15.6 MB 6.0 MB/s eta 0:00:01
#    ------------------------------ --------- 12.1/15.6 MB 5.8 MB/s eta 0:00:01
#    ------------------------------- -------- 12.3/15.6 MB 5.5 MB/s eta 0:00:01
#    -------------------------------- ------- 12.8/15.6 MB 5.0 MB/s eta 0:00:01
#    --------------------------------- ------ 13.1/15.6 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.4/15.6 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.6/15.6 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------ --- 14.2/15.6 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------ --- 14.4/15.6 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.6 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 15.2/15.6 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 15.6/15.6 MB 3.7 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.0
#     Uninstalling numpy-2.2.0:
#       Successfully uninstalled numpy-2.2.0
# Successfully installed numpy-2.0.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.16.1 requires numpy<2.0.0,>=1.26.0; python_version >= "3.12", but you have numpy 2.0.2 which is incompatible.

# %% [markdown]
# # Parts of Speech Tagging

# %%
nlp = spacy.load("en_core_web_lg")

one_block = cleanedSentences[1300:5200]
doc_block = nlp(one_block)
spacy.displacy.render(doc_block, style= 'ent', jupyter= True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">upgrade project migration applications
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ntt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  cloud premises
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aws
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  cloud worked shell scripting various application requirement working
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ansible jenkins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  automated start stop various activities application basic knowledge docker applying ssl certificates new released applications worked elastic search configuration
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     peoplesoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  gained knowledge
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aws
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  resources strong understanding unix architecture command trouble shooting unix linux platform efficient using configuration management deployment tool like ansible good experience job scheduling via crontab
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ibm tivoli workload
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  scheduler
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tws
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  good knowledge automation using shell scripting continuous integration management using
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jenkins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  installing configuring
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jenkins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  responsible writing
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ansible
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  playbook perform various task managed administration tasks installation configuration applications troubleshooting performance related issue applying tuxedo weblogic cpu patches various applications working vulnerabilities reported security teams reviewing platform certification information products platforms database servers web application servers browsers products peopletools server migration
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aws amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  web service installation
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     peoplesoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  server components application servers process scheduler servers tuxedo web logic servers new release peopletools
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     unix linux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  servers applying latest patch peopletools installing configuring change assistant various upgrade passes creating running peopletools upgrade job peopletools upgrade setting performance monitor creating new app web process scheduler domains post upgrade new linux severs troubleshooting common domain boot problems identifying configuring source target databases
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hcm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  application upgrade working
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hcm pum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  images creating change packages using pum applying source target databases per requirement creating application upgrade job using change assistant
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     srdt pvt ltd srm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  group role project
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     peoplesoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  application database admin skills
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     peoplesoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  administration
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weblogic tuxedo app
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  designer
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pum peopletools
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </

# %%
for token in doc_block[:30]:
    print(token,token.pos_)
# Out:
# upgrade VERB
# project NOUN
# migration NOUN
# applications NOUN
# ntt PROPN
# cloud PROPN
# premises NOUN
# aws PROPN
# cloud PROPN
# worked VERB
# shell NOUN
# scripting NOUN
# various ADJ
# application NOUN
# requirement NOUN
# working VERB
# ansible PROPN
# jenkins PROPN
# automated VERB
# start PROPN
# stop VERB
# various ADJ
# activities NOUN
# application VERB
# basic ADJ
# knowledge NOUN
# docker NOUN
# applying VERB
# ssl PROPN
# certificates NOUN

# %% [markdown]
# # Counting all Nouns and Verbs present in the tokens

# %%
one_block = cleanedSentences
doc_block = nlp(one_block)
nouns_verbs = [token.text for token in doc_block if token.pos_ in ('NOUN','VERB')]
print(nouns_verbs[:250])
# Out:
# ['work', 'environment', 'challenging', 'assignments', 'yield', 'benefits', 'job', 'satisfaction', 'paced', 'growth', 'experience', 'role', 'system', 'admin', 'skills', 'shell', 'scripting', 'managing', 'fscm', 'production', 'environments', 'support', 'environments', 'installed', 'windows', 'involved', 'day', 'day', 'activities', 'project', 'migration', 'database', 'refresh', 'system', 'admin', 'changes', 'tax', 'updates', 'troubleshooting', 'servers', 'application', 'servers', 'web', 'servers', 'process', 'scheduler', 'servers', 'applying', 'tuxedo', 'weblogic', 'middleware', 'cpu', 'patches', 'applications', 'working', 'shell', 'scripting', 'used', 'integration', 'method', 'exchange', 'files', 'systems', 'installation', 'troubleshooting', 'tier', 'setup', 'requirement', 'reviewing', 'vulnerabilities', 'reported', 'security', 'teams', 'renewal', 'weblogic', 'vulnerability', 'remediation', 'vulnerability', 'report', 'team', 'worked', 'update', 'manager', 'installation', 'working', 'knowledge', 'docker', 'developing', 'shell', 'scripts', 'troubleshooting', 'shell', 'script', 'failures', 'techmahindra', 'role', 'project', 'application', 'support', 'automation', 'devops', 'tools', 'peoplesoft', 'admin', 'skills', 'shell', 'scripting', 'project', 'people', 'tools', 'upgrade', 'hcm', 'application', 'upgrade', 'project', 'migration', 'applications', 'premises', 'worked', 'shell', 'scripting', 'application', 'requirement', 'working', 'automated', 'stop', 'activities', 'application', 'knowledge', 'docker', 'applying', 'certificates', 'released', 'applications', 'worked', 'search', 'configuration', 'gained', 'knowledge', 'resources', 'understanding', 'unix', 'architecture', 'command', 'trouble', 'shooting', 'platform', 'using', 'configuration', 'management', 'deployment', 'tool', 'experience', 'job', 'scheduling', 'workload', 'automation', 'using', 'scripting', 'integration', 'management', 'using', 'installing', 'configuring', 'writing', 'playbook', 'perform', 'task', 'managed', 'administration', 'tasks', 'installation', 'configuration', 'applications', 'troubleshooting', 'performance', 'related', 'issue', 'applying', 'tuxedo', 'cpu', 'patches', 'applications', 'working', 'vulnerabilities', 'reported', 'security', 'teams', 'reviewing', 'platform', 'certification', 'information', 'products', 'platforms', 'database', 'servers', 'web', 'application', 'servers', 'browsers', 'products', 'peopletools', 'server', 'web', 'service', 'installation', 'server', 'components', 'application', 'servers', 'process', 'scheduler', 'servers', 'tuxedo', 'web', 'logic', 'servers', 'release', 'peopletools', 'servers', 'applying', 'patch', 'peopletools', 'installing', 'configuring', 'change', 'upgrade', 'passes', 'creating', 'running', 'peopletools', 'upgrade', 'job', 'peopletools', 'upgrade', 'setting', 'performance', 'monitor', 'creating', 'app', 'web', 'process', 'scheduler', 'domains', 'post', 'upgrade', 'severs', 'troubleshooting', 'domain', 'boot']

# %%
cv = CountVectorizer()
X = cv.fit_transform(nouns_verbs)
sum_words = X.sum(axis=0)

words_freq = [(word,sum_words[0,idx]) for word, idx in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)

wd_df = pd.DataFrame(words_freq)
wd_df.columns = ['Words','Count']
wd_df[0:15]
# Out:
#           Words  Count
# 0    experience    281
# 1         using    240
# 2   application    185
# 3       reports    164
# 4          data    159
# 5       project    158
# 6      business    149
# 7       workday    147
# 8           web    125
# 9       process    119
# 10    knowledge    107
# 11        react    107
# 12       skills    100
# 13     involved     96
# 14      working     95

# %%
import pylab

# %%
fig, axe = plt.subplots(1,1, figsize=(10,7), dpi=200)
ax = sns.barplot(x= wd_df['Count'].head(20), y= wd_df.Words.head(20), data= wd_df, ax = axe,
            label= 'Total Pofile Category : {}'.format(len(resume_data.Category.unique())))

axe.set_xlabel('Frequency', size=16,fontweight= 'bold')
axe.set_ylabel('Words', size=16, fontweight= 'bold')
plt.xticks(rotation = 0)
plt.legend(loc='best', fontsize= 'x-large')
plt.title('Top 25 Most used Nouns and Verbs in Resumes', fontsize= 18, fontweight= 'bold')
rcParams = {'xtick.labelsize':'14','ytick.labelsize':'14','axes.labelsize':'16'}

for i in ax.containers:
    ax.bar_label(i,color = 'black', fontweight = 'bold', fontsize= 12)

pylab.rcParams.update(rcParams)
fig.tight_layout()
plt.show()
fig.savefig('noun_and_verb.png', dpi = 500)

# %%
text = " ".join(cat for cat in wd_df.Words) # Creating the text variable

word_cloud = WordCloud(width=1000, height=800, random_state=10, background_color="black", 
                       colormap="Pastel1", collocations=False, stopwords=STOPWORDS).generate(text)

plt.figure(figsize=(10,7), dpi=800) # Display the generated Word Cloud
plt.title('Most used Nouns and Verbs in Resumes', fontsize= 15, fontweight= 'bold')
plt.imshow(word_cloud)
plt.axis("off")

word_cloud.to_file('noun_and_verb.png')
plt.show()
